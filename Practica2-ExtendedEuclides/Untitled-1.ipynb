# %% [markdown]
# # Practica no.5 ---> Objetos distribuidos
#
# # Practica no.6 ---> Servicios / Servicios Web
#
#
# Se debe implementar un Stub y un skeleton, junto con un broker, principalmente para mandar structuras de datos con las interfaces a un solo esquem
#
# El broker es el encargado de dar peso a cada uno de los servidores conectados, ademas de cada uno de estos el intermediario traduce y llama a un procedimiento remoto.
#
# Hacer el proyecto sobre RMI

# %% [markdown]
# # Servicios
#
# - Aplicaciones monoliticas
# - Arquitecturo orientada a servicios
# - Microservicios modernos
#
# La arquitectura oruebtada a servicios es necesrio ociupar conectados ediante ESB
# Esta hecha para que todo sea autonomo, pero tenia un bus que se saturaba, las aplicaciones ocupaban apis que es neceario para generar una sola parte
#
# En microservicios, mucho mas enfasis
#
# se empezaron a ocupar protocolos estandar, el protecolo hace que todos los sistemas entienen los datos que se pasan entre esto.
#
# PAra la comuncacion ocupamos protocolos como HTTP y formatos de texto especifico como: XML y JSON
#
# ## Sistemas SOAP
# La diferencias son la velocidad y las restricciones de cada uno.
#
# Tiene restricciones muy claras de lo que se puede transferir, teniendo uso en XML y tambien hace uso de configuracion mas avanzada y mas segura
#
# ## Sistemas Rest
# Aligera las restricciones y hace mas facil obtener.
# HAce uso de http nativo y JSON
#
#
# El uso de estos depende precisamente de la arquitectura que queremos ocupar.
#
# ## Uso de servicios web actualmente
#
# - Layer 1 : El contrato (API)
#
# - Layer 2 : El transporte (HTTP / HTTPS)
#
# - Layer 3 : El mensaje (JSON)
#
# Al server no le importa desde donde hablas sino mientras respetes el protocolo.
#
# ## componentes
#
# - Proveedores
# - Consumidores
# - Servicio de registro
# - Orquestador
# - API Gateway

# %% [markdown]
# ## Implementación de REST
#
# Es comunicación estandar
# GET, POST, DELETE y PUT
# Da todo el contenido de la pagina
#
# ## Implementacieon de GraphQl
# Se decide que se debe hacer, solicita solo lo que necesitas, pero sino existe no hace nada.
#
# ## Implementación de gRPC
# Es un framework de google todo se hace por codigos binarios, y ocuoa HTTP/2, genera el codigo para multiples lenguajes
#
#
# ## Ventajas de la arquitectura de servicios
# - Escalabilidad
# - Resistencias a Fallos
# - Desarrollo ágil
