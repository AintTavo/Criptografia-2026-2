# %% [markdown]
# # Página de inicio de sesión
#
# ## Registro
# - ¿Qué cambpos puedo solicitar
#     Investigar que campos dependiendo de la aplicación y cual es la normatividad de campos en todas las apps.
#     - nombre (ID)
#     - pwd
#     - correo
#
# - Ley findtech
#
# | ID | H(pwd) | Correo o Numero |
# | --- | --- | --- |
# | . | sha2, sha3 | . |
#
# Estándar actual es sha 3
#
# - Formas de recuperación
#     - Da click en el enlace para finalizar
#     - Código
#
# ## Inicio de Sesión
#
# - Inicio de Sesión clásico
#     - ID
#     - pwd
#
# - ¿Reestablecer tu contraseña?
#     - Mandar correo
#
# ## Sistema
#
# Foto de los integrantes en la clase de cripto
# Chisme criptografico
#
#
# Siguiente semana.
