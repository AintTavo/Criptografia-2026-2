# %% [markdown]
# # Exposión
#
# Servicios bancarios -> Ingeniero en sistemas
#
# DevSecOps - Deployment and security
#
# DevOps - Deployment
#
# Ciclos de vida de aplicaciónes
#
# CI/CD
#
# Integridad
#
# # Servicios de criptografía
#
# Integridad
# No Repudio
# Confidencialidad
#
# Auntenticación
# Disponilidad
#
# No es correcto el decir no pasar el SHA de mi aplicación,
#
# PAsar de DevOps a DevSecOps, como, que y el porque de las cosas.
#
# ## Vulnerabilidades de sistemas de computo
#
# - XSS
# - ESRF
# - OWASP - Top 10
#
# Top 10 Web
# |
# v
# LLM - Large Language Model
# SLM - Small Language Model
# Intelligent agents
# Desarrollo Moviles
#
# Todas esta areas mas tienen problemas de seguridad, independientemente del area
#
# ## Pregutnas comunes en entrevista
#
# - ¿Como consumes tus dependencias?
#
#
# ## Respuestas
# - no te van a despedir
#
# - 3AES
# - AES-CBC
#     - Cifrado
#     - Encriptar mi contraseña
#
# - AES-GCM
#
# ## Hasheo
#
# - Argon 2
#
# # Pregunta
#
# *Que espero de esta optativa?*
